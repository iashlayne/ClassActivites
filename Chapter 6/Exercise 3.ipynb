# %% [markdown]
# <a href="https://colab.research.google.com/github/iashlayne/ClassActivites/blob/main/Chapter%206/Exercise%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercise 3: Infinity

#we are doing an infinite loop :>>>
a = 1
name = input("what’s your name?")
while a == 1:
    print("Hi " + name + ", this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)")
# Out:
# Streaming output truncated to the last 5000 lines.
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# ...
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
# Hi yang, this is an infinite loop! (To end the loop, press ctrl-C or close the window displaying the output.)
